# %%
# Make suitable changes here. My .csv file is in :  My Drive/Colab Notebooks
from google.colab import drive
drive.mount("/content/drive/")
# %cd '/content/drive/My Drive/Colab Notebooks'
# !pwd #Prints the present working directory
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Colab Notebooks
# /content/drive/My Drive/Colab Notebooks

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

def LinearRegressionModel(X, y, with_fit_intercept):
    # Inputs:                                                                   
    # X = N x d, d means the number of features/attributes                                                              
    # y = N x 1                                                                 
    # Output:                                                                   
    # Linear regression model
    
    # IMPLEMENT THIS METHOD USING sklearn.linear_model.LinearRegression
    clf = LinearRegression(fit_intercept=with_fit_intercept).fit(X,y)
    return clf

# load dataset
dataset = pd.read_csv('petrol_consumption.csv')

X = dataset[['Petrol_tax', 'Average_income', 'Paved_Highways', 'Population_Driver_licence(%)']]
y = dataset['Petrol_Consumption']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Scikit package
clf_without_intercept = LinearRegressionModel(X_train, y_train, False)
y_predict_train = clf_without_intercept.predict(X_train)
print('Mean Squared Error of Training (Without Intercept):', metrics.mean_squared_error(y_train, y_predict_train))
y_pred = clf_without_intercept.predict(X_test)
print('Mean Squared Error of Testing (Without Intercept):', metrics.mean_squared_error(y_test, y_pred))

clf_with_intercept = LinearRegressionModel(X_train, y_train, True)
y_predict_train = clf_with_intercept.predict(X_train)
print('Mean Squared Error of Training (With Intercept):', metrics.mean_squared_error(y_train, y_predict_train))
y_pred = clf_with_intercept.predict(X_test) 
print('Mean Squared Error of Testing (With Intercept):', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error of Training (Without Intercept): 4336.068548626841
# Mean Squared Error of Testing (Without Intercept): 4492.950158508002
# Mean Squared Error of Training (With Intercept): 3822.6904553362224
# Mean Squared Error of Testing (With Intercept): 4666.344787588362
